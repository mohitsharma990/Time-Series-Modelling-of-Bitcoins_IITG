# %% [markdown]
# # HYBRID MODEL

# %%
# Cases Considered :
# The code provides COBRA model in High-dimensional Time series setup
# Multivariate prediction is of two types : (1) One dimensional output  !! (2) high-dimensional output space.
# The following program deals with high-dimensional output space.
# Pred.Cases : Prediction can be of two types. (i) direct n step prediction [Output space n dimensional] (ii) One step prediction.
#***** The following program deals with high-dimensional output space : Type (1)  Encoder decoder dynamic evolution with one step prediction.
#**** The following program deals with high-dimensional output space : Type (1)  Direct n step of m vectors.  Prediction dimension : (n, m).
# The following program deals with high-dimensional output space : Type (2)  Filter at same step/One step based on all.  Output dimension can be one or more.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.impute import KNNImputer

import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras import layers, models
from tensorflow.keras.layers import Dense, LSTM, Dropout

from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import GridSearchCV
from sklearn.base import BaseEstimator

import warnings
warnings.filterwarnings('ignore')

# %%
df_raw = pd.read_csv("Bitcoin_data.csv")
df_raw.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-12-27 23:59:59  777.510010  713.599976
# 1    2  Bitcoin    BTC  2013-12-28 23:59:59  747.059998  705.349976
# 2    3  Bitcoin    BTC  2013-12-29 23:59:59  748.609985  714.440002
# 3    4  Bitcoin    BTC  2013-12-30 23:59:59  766.599976  740.239990
# 4    5  Bitcoin    BTC  2013-12-31 23:59:59  760.580017  738.169983
#
#          Open       Close      Volume     Marketcap
# 0  763.280029  735.070007  46862700.0  8.955395e+09
# 1  737.979980  727.830017  32505800.0  8.869919e+09
# 2  728.049988  745.049988  19011300.0  9.082104e+09
# 3  741.349976  756.130005  20707700.0  9.217168e+09
# 4  760.320007  754.010010  20897300.0  9.191325e+09

# %%
df_raw = df_raw.drop(columns=['SNo','Name','Symbol'])
df_orig = pd.read_csv("Bitcoin_data.csv")

df_raw['Date'] = pd.to_datetime(df_raw['Date']).dt.date
df_orig['Date'] = pd.to_datetime(df_orig['Date']).dt.date

# %%
print(df_raw.head())
# Out:
#          Date        High         Low        Open       Close      Volume  \
# 0  2013-12-27  777.510010  713.599976  763.280029  735.070007  46862700.0
# 1  2013-12-28  747.059998  705.349976  737.979980  727.830017  32505800.0
# 2  2013-12-29  748.609985  714.440002  728.049988  745.049988  19011300.0
# 3  2013-12-30  766.599976  740.239990  741.349976  756.130005  20707700.0
# 4  2013-12-31  760.580017  738.169983  760.320007  754.010010  20897300.0
#
#       Marketcap
# 0  8.955395e+09
# 1  8.869919e+09
# 2  9.082104e+09
# 3  9.217168e+09
# 4  9.191325e+09

# %%
df_orig.head()
# Out:
#    SNo     Name Symbol        Date        High         Low        Open  \
# 0    1  Bitcoin    BTC  2013-12-27  777.510010  713.599976  763.280029
# 1    2  Bitcoin    BTC  2013-12-28  747.059998  705.349976  737.979980
# 2    3  Bitcoin    BTC  2013-12-29  748.609985  714.440002  728.049988
# 3    4  Bitcoin    BTC  2013-12-30  766.599976  740.239990  741.349976
# 4    5  Bitcoin    BTC  2013-12-31  760.580017  738.169983  760.320007
#
#         Close      Volume     Marketcap
# 0  735.070007  46862700.0  8.955395e+09
# 1  727.830017  32505800.0  8.869919e+09
# 2  745.049988  19011300.0  9.082104e+09
# 3  756.130005  20707700.0  9.217168e+09
# 4  754.010010  20897300.0  9.191325e+09

# %%
# helper functions

# %%
def getratio(data):
  ratios = []
  ratios.append(1)
  for i in range(1,len(data)):
    if data[i] ==0 or data[i-1] ==0:
      ratios.append(np.nan)
    else:
      ratios.append(data[i]/data[i-1])
  return ratios

# %%
def takeratio(df, col1, col2):
  temp = []
  for i in range(len(df)):
    temp.append(df.loc[i,col1]/df.loc[i,col2])
  return temp

# %%
def preprocess(dataf):
  df1 = dataf.copy()
  #Get the the total number of shares in the market using market cap and closing price 
  num_shares = list()
  for i in range(len(df1)):
    num_shares.append(df1.loc[i,'Marketcap']/df1.loc[i,'Close'])
  df1['Numshares'] = num_shares
  df1 = df1.drop(columns=['Marketcap'])
    #Create features
      # 1. ratio of x_[i] and x_[i-1] for each numeric column
  for col in df1.columns:
    if col == 'Date':
      continue
    df1[col+"_ratio"] = getratio(df1[col])
  # 2. ratio of High Low and Close Open
  df1["HighLowRatio"] = takeratio(df1,"High","Low")
  df1["CloseOpenRatio"] = takeratio(df1,"Close","Open")
  return df1

# %%
df = preprocess(df_raw)
print(df.head())
# Out:
#          Date        High         Low        Open       Close      Volume  \
# 0  2013-12-27  777.510010  713.599976  763.280029  735.070007  46862700.0
# 1  2013-12-28  747.059998  705.349976  737.979980  727.830017  32505800.0
# 2  2013-12-29  748.609985  714.440002  728.049988  745.049988  19011300.0
# 3  2013-12-30  766.599976  740.239990  741.349976  756.130005  20707700.0
# 4  2013-12-31  760.580017  738.169983  760.320007  754.010010  20897300.0
#
#       Numshares  High_ratio  Low_ratio  Open_ratio  Close_ratio  Volume_ratio  \
# 0  1.218305e+07    1.000000   1.000000    1.000000     1.000000      1.000000
# 1  1.218680e+07    0.960837   0.988439    0.966854     0.990151      0.693639
# 2  1.218993e+07    1.002075   1.012887    0.986544     1.023659      0.584859
# 3  1.218992e+07    1.024031   1.036112    1.018268     1.014872      1.089231
# 4  1.218992e+07    0.992147   0.997204    1.025588     0.997196      1.009156
#
#    Numshares_ratio  HighLowRatio  CloseOpenRatio
# 0         1.000000      1.089560        0.963041
# 1         1.000308      1.059134        0.986246
# 2         1.000256      1.047828        1.023350
# 3         1.000000      1.035610        1.019937
# 4         1.000000      1.030359        0.991701

# %%
df = df.assign(Close_cum = df['Close'])
col = df.pop('Close_cum')
df.insert(4, 'Close_cum', col)
df['Close_cum'] = df['Close_cum'].cumsum()

df = df.assign(Volume_cum = df['Volume'])
col = df.pop('Volume_cum')
df.insert(5, 'Volume_cum', col)
df['Volume_cum'] = df['Volume_cum'].cumsum()

print(df.head())
# Out:
#          Date        High         Low        Open    Close_cum   Volume_cum  \
# 0  2013-12-27  777.510010  713.599976  763.280029   735.070007   46862700.0
# 1  2013-12-28  747.059998  705.349976  737.979980  1462.900024   79368500.0
# 2  2013-12-29  748.609985  714.440002  728.049988  2207.950012   98379800.0
# 3  2013-12-30  766.599976  740.239990  741.349976  2964.080017  119087500.0
# 4  2013-12-31  760.580017  738.169983  760.320007  3718.090027  139984800.0
#
#         Close      Volume     Numshares  High_ratio  Low_ratio  Open_ratio  \
# 0  735.070007  46862700.0  1.218305e+07    1.000000   1.000000    1.000000
# 1  727.830017  32505800.0  1.218680e+07    0.960837   0.988439    0.966854
# 2  745.049988  19011300.0  1.218993e+07    1.002075   1.012887    0.986544
# 3  756.130005  20707700.0  1.218992e+07    1.024031   1.036112    1.018268
# 4  754.010010  20897300.0  1.218992e+07    0.992147   0.997204    1.025588
#
#    Close_ratio  Volume_ratio  Numshares_ratio  HighLowRatio  CloseOpenRatio
# 0     1.000000      1.000000         1.000000      1.089560        0.963041
# 1     0.990151      0.693639         1.000308      1.059134        0.986246
# 2     1.023659      0.584859         1.000256      1.047828        1.023350
# 3     1.014872      1.089231         1.000000      1.035610        1.019937
# 4     0.997196      1.009156         1.000000      1.030359        0.991701

# %%
'''Create indexes to split dataset'''

times = sorted(df.index.values)
last_20pct = sorted(df.index.values)[-int(0.2*len(times))] # Last 20% of series
last_10pct = sorted(df.index.values)[-int(0.1*len(times))] # Last 10% of series

df_train = df[(df.index < last_20pct)]  # Training data are 80% of total data
df_val = df[(df.index >= last_20pct) & (df.index < last_10pct)]
df_test = df[(df.index >= last_10pct)]

temp = df_train.drop(columns=['Date']).copy()
imputer = KNNImputer(n_neighbors=3, weights="uniform", missing_values=df.loc[3,'Volume_ratio'])
imputer.fit(temp)
# Out:
# KNNImputer(missing_values=1.089231141479015, n_neighbors=3)

# %%
def fillnans(imputer, data):
  temp = data.drop(columns=['Date']).copy()
  data.loc[:,data.columns[1:]] = imputer.transform(temp)
  data = data.set_index('Date')
  return data

# %%
df_train = fillnans(imputer, df_train)
df_train = df_train.tail(-1)
df_val = fillnans(imputer, df_val)
df_test = fillnans(imputer, df_test)

# %%
# Convert pandas columns into arrays
train_data = df_train.values
val_data = df_val.values
test_data = df_test.values
print('Training data shape: {}'.format(train_data.shape))
print('Validation data shape: {}'.format(val_data.shape))
print('Test data shape: {}'.format(test_data.shape))

print(train_data[:, 5])
print(df_train['Close'])
# Out:
# Training data shape: (2199, 16)
# Validation data shape: (275, 16)
# Test data shape: (274, 16)
# [ 727.83001709  745.04998779  756.13000488 ... 6985.47000061 7344.88418341
#  7410.65656642]
# Date
# 2013-12-28     727.830017
# 2013-12-29     745.049988
# 2013-12-30     756.130005
# 2013-12-31     754.010010
# 2014-01-01     771.400024
#                  ...
# 2019-12-31    7193.598978
# 2020-01-01    7200.174393
# 2020-01-02    6985.470001
# 2020-01-03    7344.884183
# 2020-01-04    7410.656566
# Name: Close, Length: 2199, dtype: float64

# %%
fig = plt.figure(figsize=(15,12))
st = fig.suptitle("Train Test Val Separation", fontsize=20)
st.set_y(0.95)

###############################################################################

ax1 = fig.add_subplot(211)
ax1.plot(np.arange(train_data.shape[0]), train_data[:, 5], label='Training data')

ax1.plot(np.arange(train_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]), val_data[:, 5], label='Validation data')

ax1.plot(np.arange(train_data.shape[0]+val_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]+test_data.shape[0]), test_data[:, 5], label='Test data')
ax1.set_xlabel('Date')
ax1.set_ylabel('Closing Returns')
ax1.set_title("Close Price", fontsize=18)
ax1.legend(loc="best", fontsize=12)

###############################################################################

ax2 = fig.add_subplot(212)
ax2.plot(np.arange(train_data.shape[0]), train_data[:, 6], label='Training data')

ax2.plot(np.arange(train_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]), val_data[:, 6], label='Validation data')

ax2.plot(np.arange(train_data.shape[0]+val_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]+test_data.shape[0]), test_data[:, 6], label='Test data')
ax2.set_xlabel('Date')
ax2.set_ylabel('Volume Changes')
ax2.set_title("Volume", fontsize=18)
ax2.legend(loc="best", fontsize=12)
#plt.savefig("1_Cum_Data_Seperation.png", dpi = 80)

plt.show()

###############################################################################

# %%
fig = plt.figure(figsize=(15, 12))
st = fig.suptitle("Train Test Val Separation (relative jump from the previous day)", fontsize=20)
st.set_y(0.95)

ax1 = fig.add_subplot(211)
ax1.plot(np.arange(train_data.shape[0]), df_train['Close_ratio'], label='Training data')

ax1.plot(np.arange(train_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]), df_val['Close_ratio'], label='Validation data')

ax1.plot(np.arange(train_data.shape[0]+val_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]+test_data.shape[0]), df_test['Close_ratio'], label='Test data')
ax1.set_xlabel('Date')
ax1.set_ylabel('Relative Closing Returns')
ax1.set_title("Close Price", fontsize=18)
ax1.legend(loc="best", fontsize=12)


###############################################################################

ax2 = fig.add_subplot(212)
ax2.plot(np.arange(train_data.shape[0]), df_train['Volume_ratio'], label='Training data')

ax2.plot(np.arange(train_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]), df_val['Volume_ratio'], label='Validation data')

ax2.plot(np.arange(train_data.shape[0]+val_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]+test_data.shape[0]), df_test['Volume_ratio'], label='Test data')
                   
ax2.set_xlabel('Date')
ax2.set_ylabel('Relative Volume Changes')
ax2.set_title("Volume", fontsize=18)
ax2.legend(loc="best", fontsize=12)

#plt.savefig("1_Cum_Relative_Data_Seperation.png", dpi = 80)

plt.show()


###############################################################################

# %%
look_back=20

xtrain = np.reshape(np.array(train_data[:,3:5]), (train_data.shape[0], 2))
xval = np.reshape(np.array(val_data[:, 3:5]), (val_data.shape[0], 2))
xtest = np.reshape(np.array(test_data[:, 3:5]), (test_data.shape[0], 2))


dim = xtrain.shape[1]
print(dim)
# Out:
# 2

# %%
# For Multivariate set up
def create_dataset_for_lstm(dataset, look_back=20):
    dataX, dataY, scalers = [], [], []
    dataset = np.array(dataset)
    for i in range(dataset.shape[0]-look_back-1):
        a = dataset[i:(i+look_back)]
        scaler = MinMaxScaler(feature_range=(0,1))
        b = scaler.fit_transform(a)
        dataX.append(b)
        y = scaler.transform([dataset[i + look_back]])
        y = np.reshape(y, (y.shape[1]))
        dataY.append(y)
        scalers.append(scaler)
    return np.array(dataX), np.array(dataY), np.array(scalers)

# %%
# Let's call this as ToplayerVersion 1 : forward pass in highway


X_train, y_train, scalers_train = create_dataset_for_lstm(xtrain, look_back)
X_val, y_val, scalers_val = create_dataset_for_lstm(xval, look_back)
X_test, y_test, scalers_test = create_dataset_for_lstm(xtest, look_back)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_val = np.reshape(X_val, (X_val.shape[0], X_val.shape[1], X_train.shape[2]))

print(X_train.shape[0], X_train.shape[1], X_train.shape[2])
print(y_train.shape[0], y_train.shape[1])
# Out:
# 2178 20 2
# 2178 2

# %%
model = models.Sequential()
model.add(LSTM(units = 100, use_bias=True, activation = 'relu', return_sequences = True, input_shape = (X_train.shape[1], X_train.shape[2])))
model.add(SimpleRNN(units = 100, use_bias=True, activation = 'relu', return_sequences = True, input_shape = (X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(GRU(units = 50, activation = 'relu', return_sequences = True, use_bias=True))
model.add(Dropout(0.2))
model.add(LSTM(units = 10, use_bias=True))
model.add(Dropout(0.5))
model.add(Dense(units = 2))

callback = tf.keras.callbacks.ModelCheckpoint('hybrid_baseline.hdf5', 
                                              monitor='val_loss', 
                                              save_best_only=True, 
                                              verbose=1)


model.compile(optimizer = 'Adamax', loss = 'mse', metrics = ['mae','mape'])

history = model.fit(X_train, y_train, epochs = 50, batch_size = 32, verbose=1,
                    callbacks=[callback],
                    validation_data=(X_val, y_val))
# Out:
# Epoch 1/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.2748 - mae: 0.4338 - mape: 41.1397
# Epoch 1: val_loss improved from inf to 0.03568, saving model to hybrid_baseline.hdf5
# 69/69 [==============================] - 7s 42ms/step - loss: 0.2728 - mae: 0.4316 - mape: 40.9296 - val_loss: 0.0357 - val_mae: 0.1833 - val_mape: 17.3815
# Epoch 2/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.1829 - mae: 0.3481 - mape: 32.9946
# Epoch 2: val_loss improved from 0.03568 to 0.03431, saving model to hybrid_baseline.hdf5
# 69/69 [==============================] - 2s 28ms/step - loss: 0.1829 - mae: 0.3482 - mape: 33.0131 - val_loss: 0.0343 - val_mae: 0.1807 - val_mape: 17.1400
# Epoch 3/50
# 69/69 [==============================] - ETA: 0s - loss: 0.1668 - mae: 0.3331 - mape: 31.5960
# Epoch 3: val_loss improved from 0.03431 to 0.01997, saving model to hybrid_baseline.hdf5
# 69/69 [==============================] - 2s 31ms/step - loss: 0.1668 - mae: 0.3331 - mape: 31.5960 - val_loss: 0.0200 - val_mae: 0.1377 - val_mape: 13.0547
# Epoch 4/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.1481 - mae: 0.3121 - mape: 29.5887
# Epoch 4: val_loss did not improve from 0.01997
# 69/69 [==============================] - 2s 30ms/step - loss: 0.1481 - mae: 0.3122 - mape: 29.5965 - val_loss: 0.0249 - val_mae: 0.1534 - val_mape: 14.5408
# Epoch 5/50
# 69/69 [==============================] - ETA: 0s - loss: 0.1560 - mae: 0.3201 - mape: 30.3388
# Epoch 5: val_loss improved from 0.01997 to 0.01639, saving model to hybrid_baseline.hdf5
# 69/69 [==============================] - 3s 39ms/step - loss: 0.1560 - mae: 0.3201 - mape: 30.3388 - val_loss: 0.0164 - val_mae: 0.1248 - val_mape: 11.8343
# Epoch 6/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.1324 - mae: 0.2952 - mape: 27.9823
# Epoch 6: val_loss improved from 0.01639 to 0.01291, saving model to hybrid_baseline.hdf5
# 69/69 [==============================] - 2s 29ms/step - loss: 0.1326 - mae: 0.2954 - mape: 28.0023 - val_loss: 0.0129 - val_mae: 0.1119 - val_mape: 10.6056
# Epoch 7/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.1235 - mae: 0.2848 - mape: 27.0065
# Epoch 7: val_loss did not improve from 0.01291
# 69/69 [==============================] - 2s 29ms/step - loss: 0.1235 - mae: 0.2847 - mape: 26.9979 - val_loss: 0.0166 - val_mae: 0.1268 - val_mape: 12.0189
# Epoch 8/50
# 69/69 [==============================] - ETA: 0s - loss: 0.1185 - mae: 0.2802 - mape: 26.5685
# Epoch 8: val_loss did not improve from 0.01291
# 69/69 [==============================] - 2s 29ms/step - loss: 0.1185 - mae: 0.2802 - mape: 26.5685 - val_loss: 0.0150 - val_mae: 0.1200 - val_mape: 11.3764
# Epoch 9/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.1077 - mae: 0.2664 - mape: 25.2676
# Epoch 9: val_loss improved from 0.01291 to 0.00857, saving model to hybrid_baseline.hdf5
# 69/69 [==============================] - 2s 29ms/step - loss: 0.1076 - mae: 0.2661 - mape: 25.2299 - val_loss: 0.0086 - val_mae: 0.0901 - val_mape: 8.5375
# Epoch 10/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.1014 - mae: 0.2571 - mape: 24.3787
# Epoch 10: val_loss improved from 0.00857 to 0.00818, saving model to hybrid_baseline.hdf5
# 69/69 [==============================] - 2s 29ms/step - loss: 0.1013 - mae: 0.2570 - mape: 24.3639 - val_loss: 0.0082 - val_mae: 0.0883 - val_mape: 8.3708
# Epoch 11/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0991 - mae: 0.2532 - mape: 24.0078
# Epoch 11: val_loss improved from 0.00818 to 0.00723, saving model to hybrid_baseline.hdf5
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0991 - mae: 0.2531 - mape: 23.9988 - val_loss: 0.0072 - val_mae: 0.0838 - val_mape: 7.9380
# Epoch 12/50
# 69/69 [==============================] - ETA: 0s - loss: 0.0973 - mae: 0.2505 - mape: 23.7550
# Epoch 12: val_loss did not improve from 0.00723
# 69/69 [==============================] - 2s 30ms/step - loss: 0.0973 - mae: 0.2505 - mape: 23.7550 - val_loss: 0.0167 - val_mae: 0.1284 - val_mape: 12.1803
# Epoch 13/50
# 68/69 [============================>.] - ETA: 0s - loss: 0.0825 - mae: 0.2319 - mape: 21.9918
# Epoch 13: val_loss did not improve from 0.00723
# 69/69 [==============================] - 2s 35ms/step - loss: 0.0825 - mae: 0.2319 - mape: 21.9932 - val_loss: 0.0147 - val_mae: 0.1206 - val_mape: 11.4359
# Epoch 14/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0797 - mae: 0.2268 - mape: 21.5088
# Epoch 14: val_loss improved from 0.00723 to 0.00572, saving model to hybrid_baseline.hdf5
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0799 - mae: 0.2271 - mape: 21.5357 - val_loss: 0.0057 - val_mae: 0.0743 - val_mape: 7.0456
# Epoch 15/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0778 - mae: 0.2246 - mape: 21.3016
# Epoch 15: val_loss did not improve from 0.00572
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0776 - mae: 0.2243 - mape: 21.2716 - val_loss: 0.0093 - val_mae: 0.0952 - val_mape: 9.0297
# Epoch 16/50
# 69/69 [==============================] - ETA: 0s - loss: 0.0760 - mae: 0.2232 - mape: 21.1598
# Epoch 16: val_loss did not improve from 0.00572
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0760 - mae: 0.2232 - mape: 21.1598 - val_loss: 0.0084 - val_mae: 0.0907 - val_mape: 8.5966
# Epoch 17/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0733 - mae: 0.2190 - mape: 20.7681
# Epoch 17: val_loss did not improve from 0.00572
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0732 - mae: 0.2190 - mape: 20.7669 - val_loss: 0.0110 - val_mae: 0.1041 - val_mape: 9.8716
# Epoch 18/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0687 - mae: 0.2121 - mape: 20.1036
# Epoch 18: val_loss did not improve from 0.00572
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0686 - mae: 0.2120 - mape: 20.1034 - val_loss: 0.0069 - val_mae: 0.0821 - val_mape: 7.7825
# Epoch 19/50
# 69/69 [==============================] - ETA: 0s - loss: 0.0668 - mae: 0.2096 - mape: 19.8732
# Epoch 19: val_loss did not improve from 0.00572
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0668 - mae: 0.2096 - mape: 19.8732 - val_loss: 0.0076 - val_mae: 0.0864 - val_mape: 8.1942
# Epoch 20/50
# 69/69 [==============================] - ETA: 0s - loss: 0.0620 - mae: 0.2017 - mape: 19.1205
# Epoch 20: val_loss improved from 0.00572 to 0.00444, saving model to hybrid_baseline.hdf5
# 69/69 [==============================] - 2s 33ms/step - loss: 0.0620 - mae: 0.2017 - mape: 19.1205 - val_loss: 0.0044 - val_mae: 0.0653 - val_mape: 6.1916
# Epoch 21/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0611 - mae: 0.1984 - mape: 18.8115
# Epoch 21: val_loss did not improve from 0.00444
# 69/69 [==============================] - 2s 32ms/step - loss: 0.0612 - mae: 0.1984 - mape: 18.8128 - val_loss: 0.0094 - val_mae: 0.0962 - val_mape: 9.1227
# Epoch 22/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0545 - mae: 0.1867 - mape: 17.7019
# Epoch 22: val_loss did not improve from 0.00444
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0543 - mae: 0.1864 - mape: 17.6714 - val_loss: 0.0071 - val_mae: 0.0832 - val_mape: 7.8833
# Epoch 23/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0531 - mae: 0.1863 - mape: 17.6689
# Epoch 23: val_loss did not improve from 0.00444
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0529 - mae: 0.1860 - mape: 17.6420 - val_loss: 0.0054 - val_mae: 0.0727 - val_mape: 6.8860
# Epoch 24/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0490 - mae: 0.1783 - mape: 16.8993
# Epoch 24: val_loss improved from 0.00444 to 0.00243, saving model to hybrid_baseline.hdf5
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0492 - mae: 0.1786 - mape: 16.9269 - val_loss: 0.0024 - val_mae: 0.0475 - val_mape: 4.5012
# Epoch 25/50
# 69/69 [==============================] - ETA: 0s - loss: 0.0462 - mae: 0.1734 - mape: 16.4387
# Epoch 25: val_loss did not improve from 0.00243
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0462 - mae: 0.1734 - mape: 16.4387 - val_loss: 0.0078 - val_mae: 0.0870 - val_mape: 8.2505
# Epoch 26/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0431 - mae: 0.1671 - mape: 15.8375
# Epoch 26: val_loss did not improve from 0.00243
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0430 - mae: 0.1670 - mape: 15.8247 - val_loss: 0.0056 - val_mae: 0.0739 - val_mape: 7.0047
# Epoch 27/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0417 - mae: 0.1647 - mape: 15.6165
# Epoch 27: val_loss did not improve from 0.00243
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0416 - mae: 0.1645 - mape: 15.5928 - val_loss: 0.0035 - val_mae: 0.0578 - val_mape: 5.4803
# Epoch 28/50
# 69/69 [==============================] - ETA: 0s - loss: 0.0391 - mae: 0.1588 - mape: 15.0463
# Epoch 28: val_loss did not improve from 0.00243
# 69/69 [==============================] - 3s 37ms/step - loss: 0.0391 - mae: 0.1588 - mape: 15.0463 - val_loss: 0.0035 - val_mae: 0.0575 - val_mape: 5.4490
# Epoch 29/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0345 - mae: 0.1492 - mape: 14.1366
# Epoch 29: val_loss did not improve from 0.00243
# 69/69 [==============================] - 2s 31ms/step - loss: 0.0344 - mae: 0.1489 - mape: 14.1107 - val_loss: 0.0049 - val_mae: 0.0686 - val_mape: 6.5057
# Epoch 30/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0337 - mae: 0.1478 - mape: 14.0167
# Epoch 30: val_loss did not improve from 0.00243
# 69/69 [==============================] - 2s 32ms/step - loss: 0.0337 - mae: 0.1478 - mape: 14.0070 - val_loss: 0.0056 - val_mae: 0.0740 - val_mape: 7.0108
# Epoch 31/50
# 69/69 [==============================] - ETA: 0s - loss: 0.0322 - mae: 0.1457 - mape: 13.8120
# Epoch 31: val_loss did not improve from 0.00243
# 69/69 [==============================] - 2s 30ms/step - loss: 0.0322 - mae: 0.1457 - mape: 13.8120 - val_loss: 0.0028 - val_mae: 0.0516 - val_mape: 4.8857
# Epoch 32/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0303 - mae: 0.1386 - mape: 13.1391
# Epoch 32: val_loss did not improve from 0.00243
# 69/69 [==============================] - 2s 28ms/step - loss: 0.0302 - mae: 0.1383 - mape: 13.1113 - val_loss: 0.0039 - val_mae: 0.0610 - val_mape: 5.7789
# Epoch 33/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0287 - mae: 0.1361 - mape: 12.8981
# Epoch 33: val_loss did not improve from 0.00243
# 69/69 [==============================] - 2s 28ms/step - loss: 0.0288 - mae: 0.1364 - mape: 12.9271 - val_loss: 0.0029 - val_mae: 0.0527 - val_mape: 4.9914
# Epoch 34/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0262 - mae: 0.1311 - mape: 12.4180
# Epoch 34: val_loss did not improve from 0.00243
# 69/69 [==============================] - 2s 32ms/step - loss: 0.0261 - mae: 0.1309 - mape: 12.4026 - val_loss: 0.0045 - val_mae: 0.0658 - val_mape: 6.2366
# Epoch 35/50
# 69/69 [==============================] - ETA: 0s - loss: 0.0253 - mae: 0.1281 - mape: 12.1378
# Epoch 35: val_loss did not improve from 0.00243
# 69/69 [==============================] - 2s 31ms/step - loss: 0.0253 - mae: 0.1281 - mape: 12.1378 - val_loss: 0.0035 - val_mae: 0.0579 - val_mape: 5.4837
# Epoch 36/50
# 68/69 [============================>.] - ETA: 0s - loss: 0.0228 - mae: 0.1219 - mape: 11.5468
# Epoch 36: val_loss improved from 0.00243 to 0.00128, saving model to hybrid_baseline.hdf5
# 69/69 [==============================] - 2s 36ms/step - loss: 0.0228 - mae: 0.1219 - mape: 11.5474 - val_loss: 0.0013 - val_mae: 0.0335 - val_mape: 3.1675
# Epoch 37/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0216 - mae: 0.1196 - mape: 11.3350
# Epoch 37: val_loss did not improve from 0.00128
# 69/69 [==============================] - 2s 31ms/step - loss: 0.0216 - mae: 0.1195 - mape: 11.3222 - val_loss: 0.0028 - val_mae: 0.0519 - val_mape: 4.9196
# Epoch 38/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0187 - mae: 0.1108 - mape: 10.5010
# Epoch 38: val_loss did not improve from 0.00128
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0186 - mae: 0.1105 - mape: 10.4705 - val_loss: 0.0018 - val_mae: 0.0413 - val_mape: 3.9059
# Epoch 39/50
# 69/69 [==============================] - ETA: 0s - loss: 0.0175 - mae: 0.1062 - mape: 10.0622
# Epoch 39: val_loss improved from 0.00128 to 0.00116, saving model to hybrid_baseline.hdf5
# 69/69 [==============================] - 2s 30ms/step - loss: 0.0175 - mae: 0.1062 - mape: 10.0622 - val_loss: 0.0012 - val_mae: 0.0321 - val_mape: 3.0331
# Epoch 40/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0153 - mae: 0.1002 - mape: 9.4949
# Epoch 40: val_loss did not improve from 0.00116
# 69/69 [==============================] - 2s 30ms/step - loss: 0.0154 - mae: 0.1005 - mape: 9.5259 - val_loss: 0.0026 - val_mae: 0.0493 - val_mape: 4.6710
# Epoch 41/50
# 69/69 [==============================] - ETA: 0s - loss: 0.0151 - mae: 0.0990 - mape: 9.3760
# Epoch 41: val_loss improved from 0.00116 to 0.00102, saving model to hybrid_baseline.hdf5
# 69/69 [==============================] - 2s 33ms/step - loss: 0.0151 - mae: 0.0990 - mape: 9.3760 - val_loss: 0.0010 - val_mae: 0.0300 - val_mape: 2.8368
# Epoch 42/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0136 - mae: 0.0938 - mape: 8.8868
# Epoch 42: val_loss did not improve from 0.00102
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0137 - mae: 0.0941 - mape: 8.9208 - val_loss: 0.0015 - val_mae: 0.0375 - val_mape: 3.5545
# Epoch 43/50
# 68/69 [============================>.] - ETA: 0s - loss: 0.0133 - mae: 0.0928 - mape: 8.7898
# Epoch 43: val_loss did not improve from 0.00102
# 69/69 [==============================] - 3s 37ms/step - loss: 0.0133 - mae: 0.0928 - mape: 8.7914 - val_loss: 0.0022 - val_mae: 0.0462 - val_mape: 4.3740
# Epoch 44/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0129 - mae: 0.0906 - mape: 8.5789
# Epoch 44: val_loss did not improve from 0.00102
# 69/69 [==============================] - 2s 31ms/step - loss: 0.0127 - mae: 0.0901 - mape: 8.5324 - val_loss: 0.0019 - val_mae: 0.0426 - val_mape: 4.0389
# Epoch 45/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0113 - mae: 0.0857 - mape: 8.1160
# Epoch 45: val_loss did not improve from 0.00102
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0113 - mae: 0.0854 - mape: 8.0863 - val_loss: 0.0020 - val_mae: 0.0432 - val_mape: 4.0904
# Epoch 46/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0106 - mae: 0.0825 - mape: 7.8181
# Epoch 46: val_loss improved from 0.00102 to 0.00078, saving model to hybrid_baseline.hdf5
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0106 - mae: 0.0826 - mape: 7.8252 - val_loss: 7.7953e-04 - val_mae: 0.0259 - val_mape: 2.4496
# Epoch 47/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0101 - mae: 0.0809 - mape: 7.6656
# Epoch 47: val_loss did not improve from 0.00078
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0101 - mae: 0.0808 - mape: 7.6557 - val_loss: 0.0011 - val_mae: 0.0307 - val_mape: 2.9080
# Epoch 48/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0089 - mae: 0.0758 - mape: 7.1767
# Epoch 48: val_loss improved from 0.00078 to 0.00054, saving model to hybrid_baseline.hdf5
# 69/69 [==============================] - 2s 30ms/step - loss: 0.0089 - mae: 0.0758 - mape: 7.1724 - val_loss: 5.3743e-04 - val_mae: 0.0209 - val_mape: 1.9723
# Epoch 49/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.0081 - mae: 0.0718 - mape: 6.7914
# Epoch 49: val_loss did not improve from 0.00054
# 69/69 [==============================] - 2s 28ms/step - loss: 0.0081 - mae: 0.0716 - mape: 6.7800 - val_loss: 6.3278e-04 - val_mae: 0.0230 - val_mape: 2.1715
# Epoch 50/50
# 69/69 [==============================] - ETA: 0s - loss: 0.0073 - mae: 0.0687 - mape: 6.5089
# Epoch 50: val_loss did not improve from 0.00054
# 69/69 [==============================] - 2s 30ms/step - loss: 0.0073 - mae: 0.0687 - mape: 6.5089 - val_loss: 7.4685e-04 - val_mae: 0.0254 - val_mape: 2.3976

# %%
#Calculate predication for training, validation and test data
train_pred = model.predict(X_train)
val_pred = model.predict(X_val)
test_pred = model.predict(X_test)


print(train_pred.shape)
print(val_pred.shape)
print(test_pred.shape)
# Out:
# 69/69 [==============================] - 1s 8ms/step
# 8/8 [==============================] - 0s 8ms/step
# 8/8 [==============================] - 0s 8ms/step
# (2178, 2)
# (254, 2)
# (253, 2)

# %%
# Calculate loss for all datasets
train_loss = model.evaluate(X_train, y_train, verbose=0)
val_loss = model.evaluate(X_val, y_val, verbose=0)
test_loss = model.evaluate(X_test, y_test, verbose=0)

# Calculate MAE for each target variable and dataset
from sklearn.metrics import mean_absolute_error
train_mae = mean_absolute_error(y_train, train_pred, multioutput='raw_values')
val_mae = mean_absolute_error(y_val, val_pred, multioutput='raw_values')
test_mae = mean_absolute_error(y_test, test_pred, multioutput='raw_values')

# Print evaluation metrics for all datasets
print('Evaluation metrics')
for i in range(train_mae.shape[0]):
    print('Target Variable {}:'.format(i))
    print('Test Data - Loss: {:.4f}, MAE: {:.4f}'.format(test_loss[i], test_mae[i]))
    print('Training Data - Loss: {:.4f}, MAE: {:.4f}'.format(train_loss[i], train_mae[i]))
    print('Validation Data - Loss: {:.4f}, MAE: {:.4f}'.format(val_loss[i], val_mae[i]))
# Out:
# Evaluation metrics
# Target Variable 0:
# Test Data - Loss: 0.0009, MAE: 0.0279
# Training Data - Loss: 0.0010, MAE: 0.0251
# Validation Data - Loss: 0.0007, MAE: 0.0259
# Target Variable 1:
# Test Data - Loss: 0.0264, MAE: 0.0250
# Training Data - Loss: 0.0257, MAE: 0.0264
# Validation Data - Loss: 0.0254, MAE: 0.0248

# %%
for i in range(np.array(train_pred).shape[0]):
      train_pred[i] = scalers_train[i].inverse_transform([train_pred[i]]).reshape((dim,))
      y_train[i] = scalers_train[i].inverse_transform([y_train[i]]).reshape((dim,))
      
for i in range(np.array(val_pred).shape[0]):
      val_pred[i] = scalers_val[i].inverse_transform([val_pred[i]]).reshape((dim,))
      #print(trainPredict[i])
      y_val[i] = scalers_val[i].inverse_transform([y_val[i]]).reshape((dim,))

for i in range(np.array(test_pred).shape[0]):
      test_pred[i] = scalers_test[i].inverse_transform([test_pred[i]]).reshape((dim,))
      y_test[i] = scalers_test[i].inverse_transform([y_test[i]]).reshape((dim,))

# %%
'''Display results'''
test_col = 3

fig = plt.figure(figsize=(15, 20))
st = fig.suptitle("HYBRID Model", fontsize=22)
st.set_y(0.12)

#Plot training data results
ax11 = fig.add_subplot(311)
ax11.plot(train_data[:, test_col], label='Training Data - BTC Cummulative Closing Prices')
ax11.plot(np.arange(look_back, train_pred.shape[0]+look_back), train_pred[:,0], linewidth=3, label='Predicted BTC Cummulative Closing Prices')
ax11.set_title("", fontsize=18)
ax11.set_xlabel('Date')
ax11.set_ylabel('BTC Closing Prices')
ax11.legend(loc="best", fontsize=12)


#Plot validation data results
ax21 = fig.add_subplot(312)
ax21.plot(val_data[:, test_col], label='Validation Data - BTC Cummulative Closing Prices')
ax21.plot(np.arange(look_back, val_pred.shape[0]+look_back), val_pred[:,0], linewidth=3, label='Predicted Cummulative BTC Closing Prices')
ax21.set_title("", fontsize=18)
ax21.set_xlabel('Date')
ax21.set_ylabel('BTC Closing Prices')
ax21.legend(loc="best", fontsize=12)



#Plot test data results
ax31 = fig.add_subplot(313)
ax31.plot(test_data[:, test_col], label='Test Data - BTC Cummulative Closing Prices')
ax31.plot(np.arange(look_back, test_pred.shape[0]+look_back), test_pred[:,0], linewidth=3, label='Predicted Cummulative BTC Closing Prices')
ax31.set_title("", fontsize=18)
ax31.set_xlabel('Date')
ax31.set_ylabel('BTC Closing Prices')
ax31.legend(loc="best", fontsize=12)


#plt.savefig("1_Predicted_Vs_Original_Cummulative_Closing_Series.png", dpi = 80)

plt.show()

# %%
fig = plt.figure(figsize=(15, 20))
st = fig.suptitle("HYBRID Model", fontsize=22)
st.set_y(0.12)

#Plot training data results
ax11 = fig.add_subplot(311)
ax11.plot(train_data[:, 4], label='Training Data - BTC Cummulative Volumes')
ax11.plot(np.arange(look_back, train_pred.shape[0]+look_back), train_pred[:,-1], linewidth=3, label='Predicted BTC Cummulative Volumes')
ax11.set_title("", fontsize=18)
ax11.set_xlabel('Date')
ax11.set_ylabel('BTC Cummulative Volumes')
ax11.legend(loc="best", fontsize=12)


#Plot validation data results
ax21 = fig.add_subplot(312)
ax21.plot(val_data[:, 4], label='Validation Data - BTC Cummulative Volumes')
ax21.plot(np.arange(look_back, val_pred.shape[0]+look_back), val_pred[:,-1], linewidth=3, label='Predicted BTC Cummulative Volumes')
ax21.set_title("", fontsize=18)
ax21.set_xlabel('Date')
ax21.set_ylabel('BTC Cummulative Volumes')
ax21.legend(loc="best", fontsize=12)


#Plot test data results
ax31 = fig.add_subplot(313)
ax31.plot(test_data[:, 4], label='Test Data - BTC Cummulative Volumes')
ax31.plot(np.arange(look_back, test_pred.shape[0]+look_back), test_pred[:,-1], linewidth=3, label='Predicted BTC Cummulative Volumes')
ax31.set_title("", fontsize=18)
ax31.set_xlabel('Date')
ax31.set_ylabel('BTC Cummulative Volumes')
ax31.legend(loc="best", fontsize=12)




#plt.savefig("1_Predicted_Vs_Original_Cummulative_Volume_Series.png", dpi = 80)

plt.show()

# %%
# convert cumulative data to normal data
def convert_cumulative_to_original_column_wise(cumulative_array):
    n_rows, n_cols = cumulative_array.shape
    original_array = np.zeros((n_rows, n_cols), dtype=cumulative_array.dtype)

    for i in range(n_cols):
        original_array[0, i] = cumulative_array[0, i]

        for j in range(1, n_rows):
            original_array[j, i] = cumulative_array[j, i] - cumulative_array[j-1, i]

    return original_array

# %%
train_pred = convert_cumulative_to_original_column_wise(train_pred)
test_pred = convert_cumulative_to_original_column_wise(test_pred)
val_pred = convert_cumulative_to_original_column_wise(val_pred)

xtrain = convert_cumulative_to_original_column_wise(xtrain)
xval = convert_cumulative_to_original_column_wise(xval)
xtest = convert_cumulative_to_original_column_wise(xtest)

# %%
'''Display results'''

fig = plt.figure(figsize=(12, 6))
st = fig.suptitle("HYBRID Model", fontsize=22)
st.set_y(0.12)

#Plot training data results
ax11 = fig.add_subplot(111)
ax11.plot(xtrain[:, 0], label='Training Data - BTC Closing Prices')
ax11.plot(np.arange(look_back+2, train_pred.shape[0]+look_back), train_pred[2:,0], linewidth=3, label='Predicted BTC Closing Prices')
ax11.set_title("", fontsize=18)
ax11.set_xlabel('Date')
ax11.set_ylabel('BTC Closing Prices')
ax11.legend(loc="best", fontsize=12)

plt.savefig("3_Predicted_Vs_Original_Training_Closing_Data.png", dpi = 80)

# %%
fig = plt.figure(figsize=(12, 6))
# create a plot

plt.plot(np.log(xval[21:,0]), label='Validation Data - BTC Closing Prices')
plt.plot(np.log(val_pred[2:,0]), linewidth=3, label='Predicted  - BTC Closing Prices')

# set the y-axis label and tick labels
plt.ylabel('BTC Closing Prices')
yticks = [10**i for i in range(4,5)]
plt.yticks(np.log(yticks), yticks)

plt.legend()

plt.savefig("3_Predicted_Vs_Original_Validation_Closing_Data.png", dpi = 80)

# %%
fig = plt.figure(figsize=(12, 6))
# create a plot

plt.plot(np.log(xtest[21:,0]), label='Test Data - BTC Closing Prices')
plt.plot(np.log(test_pred[2:,0]), linewidth=3, label='Predicted  - BTC Closing Prices')

# set the y-axis label and tick labels
plt.ylabel('BTC Closing Prices')
yticks = [10**i for i in range(4,5)]
plt.yticks(np.log(yticks), yticks)

plt.legend()

plt.savefig("3_Predicted_Vs_Original_Test_Closing_Data.png", dpi = 80)

# %%
fig = plt.figure(figsize=(12, 6))
st = fig.suptitle("HYBRID Model", fontsize=22)
st.set_y(0.12)

#Plot training data results
ax11 = fig.add_subplot(111)
ax11.plot(xtrain[:, 1], label='Training Data - BTC Volumes')
ax11.plot(np.arange(look_back, train_pred.shape[0]+look_back), train_pred[:,-1], linewidth=3, label='Predicted BTC Volumes')
ax11.set_title("", fontsize=18)
ax11.set_xlabel('Date')
ax11.set_ylabel('BTC Volumes')
ax11.legend(loc="best", fontsize=12)

plt.savefig("3_Predicted_Vs_Original_Training_Volume_Data.png", dpi = 80)

# %%
fig = plt.figure(figsize=(12, 6))
# create a plot

plt.plot(np.log(xval[21:,1]), label='Validation Data - BTC Volumes')
plt.plot(np.log(val_pred[2:,1]), linewidth=3, label='Predicted  - BTC Volumes')

# set the y-axis label and tick labels
plt.ylabel('BTC Volumes')
yticks = [10**i for i in range(10,12)]
plt.yticks(np.log(yticks), yticks)

plt.legend()

plt.savefig("3_Predicted_Vs_Original_Validation_Volume_Data.png", dpi = 80)

# %%
fig = plt.figure(figsize=(12, 6))
# create a plot

plt.plot(np.log(xtest[21:,1]), label='Test Data - BTC Volumes')
plt.plot(np.log(test_pred[2:,1]), linewidth=3, label='Predicted  - BTC Volumes')

# set the y-axis label and tick labels
plt.ylabel('BTC Volumes')
yticks = [10**i for i in range(10,12)]
plt.yticks(np.log(yticks), yticks)

plt.legend()

plt.savefig("3_Predicted_Vs_Original_Test_Volume_Data.png", dpi = 80)
